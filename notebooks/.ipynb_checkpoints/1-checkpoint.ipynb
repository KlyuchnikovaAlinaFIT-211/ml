# %% [markdown]
# # Лабораторная работа 1. Введение в машинное обучение. Обучение с учителем. Задача регрессии

# %% [markdown]
# <b>Традиционное предупреждение для всех лабораторных работ:</b> перед обучением моделей необходимо выполнить предварительную обработку данных, которая <b>обязательно</b> включает в себя:
# - заполнение пропущенных значений (рекомедуется логика заполнения пропусков на основе типа данных, которая использовалась в РГР по Практикуму);
# - преобразование категориальных признаков в числовые (используйте one-hot кодирование или map; используйте знания с Практикума).

# %% [markdown]
# Предобработка может включать в себя другие действия, но выполнение описанных выше действий обязательно.

# %% [markdown]
# Сделайте это один раз и сохраните в отдельный csv файл, а потом его используйте.

# %% [markdown]
# <b>Выполните следующие задания:</b>
# - загрузите датасет для регрессии, выделите целевой признак и предикторы, разбейте данные на обучающую и тестовую выборку;
# - решите задачу регрессии на ваших данных с использованием моделей sklearn (линейная регрессия + L1, L2), для моделей с регуляризациями подберите гиперпараметр;
# - решите задачу регрессии на ваших данных с использованием моделей sklearn (полиномиальная регрессия + L1, L2), для моделей с регуляризациями подберите гиперпараметр;
# - вычислите значения метрик $R^2$, MAE, MSE, RMSE, MAPE для всех обученных моделей; выберите лучшую модель;
# - самостоятельно реализуйте (желательно в виде класса) модель линейной регрессии с регуляризацией (можете выбрать L1 или L2);
# - самостоятельно реализуйте вычисление всех используемых метрик (в виде функций, принимающих два аргумента);
# - обучите вашу модель линейной регрессии на ваших данных; оцените качество с помощью реализованных вами метрик.

# %%
def d(x):
    return int(x[a:b])
#a=0
#b=4
#data['pickup_god'] = data['pickup_datetime'].map(d)
#data['dropoff_god'] = data['dropoff_datetime'].map(d)
#a=5
#b=7
#data['pickup_mes'] = data['pickup_datetime'].map(d)
#data['dropoff_mes'] = data['dropoff_datetime'].map(d)
a=8
b=10
data['pickup_day'] = data['pickup_datetime'].map(d)
data['dropoff_day'] = data['dropoff_datetime'].map(d)
a=11
b=13
data['pickup_chas'] = data['pickup_datetime'].map(d)
data['dropoff_chas'] = data['dropoff_datetime'].map(d)
a=14
b=16
data['pickup_min'] = data['pickup_datetime'].map(d)
data['dropoff_min'] = data['dropoff_datetime'].map(d)
a=17
b=19
data['pickup_sec'] = data['pickup_datetime'].map(d)
data['dropoff_sec'] = data['dropoff_datetime'].map(d)
data.head()
# Out:
#           id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0  id1080784        2.0  2016-02-29 16:40:21  2016-02-29 16:47:01
# 1  id0889885        1.0  2016-03-11 23:35:37  2016-03-11 23:53:57
# 2  id0857912        2.0  2016-02-21 17:59:33  2016-02-21 18:26:48
# 3  id3744273        2.0  2016-01-05 09:44:31  2016-01-05 10:03:32
# 4  id0232939        1.0  2016-02-17 06:42:23  2016-02-17 06:56:31
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.953918        40.778873         -73.963875
# 1                2        -73.988312        40.731743         -73.994751
# 2                2        -73.997314        40.721458         -73.948029
# 3                6        -73.961670        40.759720         -73.956779
# 4                1        -74.017120        40.708469         -73.988182
#
#    dropoff_latitude  trip_duration  pickup_day  dropoff_day  pickup_chas  \
# 0         40.771164            400          29           29           16
# 1         40.694931           1100          11           11           23
# 2         40.774918           1635          21           21           17
# 3         40.780628           1141           5            5            9
# 4         40.740631            848          17           17            6
#
#    dropoff_chas  pickup_min  dropoff_min  pickup_sec  dropoff_sec
# 0            16          40           47          21            1
# 1            23          35           53          37           57
# 2            18          59           26          33           48
# 3            10          44            3          31           32
# 4             6          42           56          23           31

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('../data/trip_duration_task.csv')
data = data.drop_duplicates()
data.head()
# Out:
#           id  vendor_id      pickup_datetime     dropoff_datetime  \
# 0  id1080784        2.0  2016-02-29 16:40:21  2016-02-29 16:47:01
# 1  id0889885        1.0  2016-03-11 23:35:37  2016-03-11 23:53:57
# 2  id0857912        2.0  2016-02-21 17:59:33  2016-02-21 18:26:48
# 3  id3744273        2.0  2016-01-05 09:44:31  2016-01-05 10:03:32
# 4  id0232939        1.0  2016-02-17 06:42:23  2016-02-17 06:56:31
#
#    passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                1        -73.953918        40.778873         -73.963875
# 1                2        -73.988312        40.731743         -73.994751
# 2                2        -73.997314        40.721458         -73.948029
# 3                6        -73.961670        40.759720         -73.956779
# 4                1        -74.017120        40.708469         -73.988182
#
#    dropoff_latitude  trip_duration
# 0         40.771164            400
# 1         40.694931           1100
# 2         40.774918           1635
# 3         40.780628           1141
# 4         40.740631            848

# %%
import time
import datetime
#s ="2016-02-29 16:47:01"
def t(s):
    return time.mktime(datetime.datetime.strptime(s, "%Y-%m-%d %H:%M:%S").timetuple())
data['dropoff_datetime']=data['dropoff_datetime'].map(t)
data['pickup_datetime']=data['pickup_datetime'].map(t)

# %%
data
# Out:
#                id  vendor_id  pickup_datetime  dropoff_datetime  \
# 0       id1080784        2.0     1.456742e+09      1.456743e+09
# 1       id0889885        1.0     1.457718e+09      1.457719e+09
# 2       id0857912        2.0     1.456056e+09      1.456058e+09
# 3       id3744273        2.0     1.451965e+09      1.451967e+09
# 4       id0232939        1.0     1.455670e+09      1.455671e+09
# ...           ...        ...              ...               ...
# 729317  id3905982        2.0     1.463816e+09      1.463816e+09
# 729318  id0102861        1.0     1.456080e+09      1.456081e+09
# 729319  id0439699        1.0     1.460725e+09      1.460726e+09
# 729320  id2078912        1.0     1.466308e+09      1.466309e+09
# 729321  id1053441        2.0     1.451647e+09      1.451649e+09
#
#         passenger_count  pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0                     1        -73.953918        40.778873         -73.963875
# 1                     2        -73.988312        40.731743         -73.994751
# 2                     2        -73.997314        40.721458         -73.948029
# 3                     6        -73.961670        40.759720         -73.956779
# 4                     1        -74.017120        40.708469         -73.988182
# ...                 ...               ...              ...                ...
# 729317                2        -73.965919        40.789780         -73.952637
# 729318                1        -73.996666        40.737434         -74.001320
# 729319                1        -73.997849        40.761696         -74.001488
# 729320                1        -74.006706        40.708244         -74.013550
# 729321                4        -74.003342        40.743839         -73.945847
#
#         dropoff_latitude  trip_duration
# 0              40.771164            400
# 1              40.694931           1100
# 2              40.774918           1635
# 3              40.780628           1141
# 4              40.740631            848
# ...                  ...            ...
# 729317         40.789181            296
# 729318         40.731911            315
# 729319         40.741207            673
# 729320         40.713814            447
# 729321         40.712841           1224
#
# [729322 rows x 10 columns]

# %%
data.drop(['id'], axis=1, inplace=True)
data.head()
# Out:
#    vendor_id  pickup_datetime  dropoff_datetime  passenger_count  \
# 0        2.0     1.456742e+09      1.456743e+09                1
# 1        1.0     1.457718e+09      1.457719e+09                2
# 2        2.0     1.456056e+09      1.456058e+09                2
# 3        2.0     1.451965e+09      1.451967e+09                6
# 4        1.0     1.455670e+09      1.455671e+09                1
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.953918        40.778873         -73.963875         40.771164
# 1        -73.988312        40.731743         -73.994751         40.694931
# 2        -73.997314        40.721458         -73.948029         40.774918
# 3        -73.961670        40.759720         -73.956779         40.780628
# 4        -74.017120        40.708469         -73.988182         40.740631
#
#    trip_duration
# 0            400
# 1           1100
# 2           1635
# 3           1141
# 4            848

# %%
for st in data.columns:
    if type(st[1]) == int:
        a=np.median(st)
    elif type(st[1]) == float:
        print(1);
        a=np.average(st)
    else:
        a=data.mode(axis= 0, numeric_only= False, dropna = True)[st][0]
def f(x):
    if pd.isna(x):
        return a
    else:
        return x
for st in data.columns:
    data[st]=data[st].map(f)

# %%
data.to_csv('../data/trip_duration_task_obr.csv')

# %%
data = pd.read_csv('../data/trip_duration_task_obr.csv').sample(20000).reset_index(drop=True)
data.drop(['Unnamed: 0'], axis=1, inplace=True)
data.head()
# Out:
#    vendor_id  pickup_datetime  dropoff_datetime  passenger_count  \
# 0        2.0     1.460558e+09      1.460558e+09                1
# 1        2.0     1.460042e+09      1.460042e+09                5
# 2        2.0     1.454192e+09      1.454194e+09                1
# 3        1.0     1.456056e+09      1.456056e+09                2
# 4      348.0     1.455974e+09      1.455975e+09                4
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.986404        40.742794         -73.978546         40.752056
# 1        -73.974937        40.760944         -73.974808         40.752747
# 2        -74.004944        40.740803         -73.977364         40.749363
# 3        -73.993530        40.752232         -73.975807         40.761204
# 4        -73.965820        40.765419         -73.966347         40.762039
#
#    trip_duration
# 0            352
# 1            499
# 2           1480
# 3            808
# 4            220

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20000 entries, 0 to 19999
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   vendor_id          20000 non-null  float64
#  1   pickup_datetime    20000 non-null  float64
#  2   dropoff_datetime   20000 non-null  float64
#  3   passenger_count    20000 non-null  int64
#  4   pickup_longitude   20000 non-null  float64
#  5   pickup_latitude    20000 non-null  float64
#  6   dropoff_longitude  20000 non-null  float64
#  7   dropoff_latitude   20000 non-null  float64
#  8   trip_duration      20000 non-null  int64
# dtypes: float64(7), int64(2)
# memory usage: 1.4 MB

# %%
data.loc[ : , data.columns != 'trip_duration'].corrwith(data['trip_duration'])
# Out:
# vendor_id           -0.001026
# pickup_datetime      0.022366
# dropoff_datetime     0.022995
# passenger_count      0.003112
# pickup_longitude     0.084023
# pickup_latitude     -0.005097
# dropoff_longitude    0.059090
# dropoff_latitude    -0.045622
# dtype: float64

# %%
from sklearn.preprocessing import scale
from sklearn.utils import shuffle
from sklearn.linear_model import LinearRegression

# %%
#data_shuffled = shuffle(data, random_state=123)
#X = scale(data_shuffled[data_shuffled.loc[ : , data.columns != 'trip_duration']])
#y = data_shuffled["trip_duration"]

# %%
y = data["trip_duration"]
X = data.drop(["trip_duration"], axis=1)

# %%
y
# Out:
# 0         352
# 1         499
# 2        1480
# 3         808
# 4         220
#          ...
# 19995     246
# 19996     850
# 19997    1392
# 19998     324
# 19999     310
# Name: trip_duration, Length: 20000, dtype: int64

# %%
X
# Out:
#        vendor_id  pickup_datetime  dropoff_datetime  passenger_count  \
# 0            2.0     1.460558e+09      1.460558e+09                1
# 1            2.0     1.460042e+09      1.460042e+09                5
# 2            2.0     1.454192e+09      1.454194e+09                1
# 3            1.0     1.456056e+09      1.456056e+09                2
# 4          348.0     1.455974e+09      1.455975e+09                4
# ...          ...              ...               ...              ...
# 19995        2.0     1.463865e+09      1.463865e+09                2
# 19996        2.0     1.458208e+09      1.458209e+09                1
# 19997        1.0     1.458437e+09      1.458438e+09                3
# 19998        2.0     1.453774e+09      1.453775e+09                2
# 19999        2.0     1.461241e+09      1.461242e+09                2
#
#        pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude
# 0            -73.986404        40.742794         -73.978546         40.752056
# 1            -73.974937        40.760944         -73.974808         40.752747
# 2            -74.004944        40.740803         -73.977364         40.749363
# 3            -73.993530        40.752232         -73.975807         40.761204
# 4            -73.965820        40.765419         -73.966347         40.762039
# ...                 ...              ...                ...               ...
# 19995        -73.979424        40.762032         -73.973244         40.755131
# 19996        -73.959351        40.772686         -73.935951         40.805458
# 19997        -73.994034        40.751282         -73.992828         40.758888
# 19998        -74.003853        40.748428         -74.005272         40.741161
# 19999        -73.984573        40.769562         -73.991142         40.760509
#
# [20000 rows x 8 columns]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# %%
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((16000, 8), (16000,), (4000, 8), (4000,))

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge

# %%
lr = LinearRegression().fit(X_train, y_train)

# %%
lr.predict(X_test)
# Out:
# array([ 418.00000008,  923.00000008, 1595.00000008, ...,  213.00000008,
#        2885.00000032,  331.00000008])

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error
from math import sqrt

# %%
y_pred = lr.predict(X_test)

# %%
print(f'MAE: {mean_absolute_error(y_test, y_pred)}')
print(f'MSE: {mean_squared_error(y_test, y_pred)}')
print(f'RMSE: {sqrt(mean_squared_error(y_test, y_pred))}')
print(f'MAPE: {mean_absolute_percentage_error(y_test, y_pred)}')
print(f'R^2: {lr.score(X_test, y_test)}')
# Out:
# MAE: 1.0788624156976568e-07
# MSE: 1.7835400828114565e-14
# RMSE: 1.335492449552395e-07
# MAPE: 2.408640584451942e-10
# R^2: 1.0

# %%
len(lr.coef_)
l=zip(data.columns, lr.coef_)
print(list(l))
# Out:
# [('vendor_id', -3.2763005518321247e-12), ('pickup_datetime', -0.9999999999999888), ('dropoff_datetime', 0.9999999999999926), ('passenger_count', -3.86846847335827e-11), ('pickup_longitude', -2.1593218177760978e-10), ('pickup_latitude', -8.884090900650686e-13), ('dropoff_longitude', 4.742939820895653e-10), ('dropoff_latitude', 2.092669660628409e-09)]

# %%
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
import numpy as np

# %%
parameters = {'alpha': np.arange(0, 1, 0.1)}

# %%
lasso_optimal = GridSearchCV(Lasso(), parameters).fit(X_train, y_train)
alpl=lasso_optimal.best_params_['alpha']
print(alpl)
# Out:
# C:\machine_learning\venv\lib\site-packages\sklearn\model_selection\_validation.py:686: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.444e+10, tolerance: 1.101e+07 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\model_selection\_validation.py:686: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.658e+10, tolerance: 1.144e+07 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\model_selection\_validation.py:686: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.355e+10, tolerance: 1.083e+07 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\model_selection\_validation.py:686: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.753e+10, tolerance: 9.628e+06 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\model_selection\_validation.py:686: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.686e+10, tolerance: 7.471e+06 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.446e+10, tolerance: 1.101e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.660e+10, tolerance: 1.144e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.357e+10, tolerance: 1.083e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.754e+10, tolerance: 9.628e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.687e+10, tolerance: 7.471e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.448e+10, tolerance: 1.101e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.662e+10, tolerance: 1.144e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.359e+10, tolerance: 1.083e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.756e+10, tolerance: 9.628e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.689e+10, tolerance: 7.471e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.449e+10, tolerance: 1.101e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.664e+10, tolerance: 1.144e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.360e+10, tolerance: 1.083e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.758e+10, tolerance: 9.628e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.690e+10, tolerance: 7.471e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.451e+10, tolerance: 1.101e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.665e+10, tolerance: 1.144e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.362e+10, tolerance: 1.083e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.759e+10, tolerance: 9.628e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.692e+10, tolerance: 7.471e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.453e+10, tolerance: 1.101e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.667e+10, tolerance: 1.144e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.364e+10, tolerance: 1.083e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.761e+10, tolerance: 9.628e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.693e+10, tolerance: 7.471e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.454e+10, tolerance: 1.101e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.669e+10, tolerance: 1.144e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.365e+10, tolerance: 1.083e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.763e+10, tolerance: 9.628e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.695e+10, tolerance: 7.471e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.456e+10, tolerance: 1.101e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.670e+10, tolerance: 1.144e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.367e+10, tolerance: 1.083e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.764e+10, tolerance: 9.628e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.696e+10, tolerance: 7.471e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.458e+10, tolerance: 1.101e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.672e+10, tolerance: 1.144e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.368e+10, tolerance: 1.083e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.766e+10, tolerance: 9.628e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.697e+10, tolerance: 7.471e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.459e+10, tolerance: 1.101e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.673e+10, tolerance: 1.144e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.370e+10, tolerance: 1.083e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.767e+10, tolerance: 9.628e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.699e+10, tolerance: 7.471e+06
#   model = cd_fast.enet_coordinate_descent(
# 0.4
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.233e+10, tolerance: 1.260e+07
#   model = cd_fast.enet_coordinate_descent(

# %%
#L1
lasso = Lasso(alpha=alpl).fit(X_train, y_train)
y_pred = lasso.predict(X_test)
print(f'MAE: {mean_absolute_error(y_test, y_pred)}')
print(f'MSE: {mean_squared_error(y_test, y_pred)}')
print(f'RMSE: {sqrt(mean_squared_error(y_test, y_pred))}')
print(f'MAPE: {mean_absolute_percentage_error(y_test, y_pred)}')
print(f'R^2: {lasso.score(X_test, y_test)}')
lasso.coef_
# Out:
# MAE: 533.4168882505469
# MSE: 7777591.081357977
# RMSE: 2788.8332831773896
# MAPE: 1.2748113467985704
# R^2: 0.01671563436405543
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.233e+10, tolerance: 1.260e+07
#   model = cd_fast.enet_coordinate_descent(
# array([ 1.27609176e-02, -3.75687733e-04,  3.91314802e-04,  7.44087894e+00,
#         4.60520744e+03, -8.32335088e-01,  3.24494992e+03, -4.78609998e+03])

# %%
ridge_optimal = GridSearchCV(Ridge(), parameters).fit(X_train, y_train)
alpr=ridge_optimal.best_params_['alpha']
print(alpr)
# Out:
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.11298e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.12835e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.16768e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.15826e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.8369e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.13164e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.1471e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.18647e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.17708e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.85527e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.15031e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.16585e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.20527e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.19591e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.87365e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.16899e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.1846e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.22408e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.21474e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.89204e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.18767e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.20336e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.24289e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.23357e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.91043e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.20635e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.22213e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.26171e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.25241e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.92884e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.22504e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.2409e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.28053e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.27125e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.94726e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.24374e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.25967e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.29935e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.2901e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.96568e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.26244e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.27845e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.31818e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.30895e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.2844e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.28114e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.29724e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.33702e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.32781e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# 0.0
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.30342e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.14078e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T

# %%
#L2
ridge = Ridge(alpha=alpr).fit(X_train, y_train)
y_pred = ridge.predict(X_test)
print(f'MAE: {mean_absolute_error(y_test, y_pred)}')
print(f'MSE: {mean_squared_error(y_test, y_pred)}')
print(f'RMSE: {sqrt(mean_squared_error(y_test, y_pred))}')
print(f'MAPE: {mean_absolute_percentage_error(y_test, y_pred)}')
print(f'R^2: {ridge.score(X_test, y_test)}')
ridge.coef_
# Out:
# MAE: 1.718594763295833e-07
# MSE: 1.7728816062999139e-13
# RMSE: 4.210560065240625e-07
# MAPE: 3.123453858974774e-10
# R^2: 1.0
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=2.14078e-17): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# array([ 2.09341773e-12, -1.00000000e+00,  1.00000000e+00,  1.09267070e-09,
#         6.67058225e-07, -1.13490857e-10,  4.97145832e-07, -7.28806997e-07])

# %%
#Poli
from sklearn.preprocessing import PolynomialFeatures
#y = y.values.reshape(-1,1)
#X = X.values.reshape(-1,1)
p = PolynomialFeatures(2)
X_p=p.fit_transform(X_train) 
X_p
# Out:
# array([[ 1.00000000e+00,  2.00000000e+00,  1.45334846e+09, ...,
#          5.47687061e+03, -3.01405742e+03,  1.65871038e+03],
#        [ 1.00000000e+00,  1.00000000e+00,  1.46338535e+09, ...,
#          5.47095499e+03, -3.01567855e+03,  1.66229061e+03],
#        [ 1.00000000e+00,  2.00000000e+00,  1.45284350e+09, ...,
#          5.47334117e+03, -3.01534723e+03,  1.66120083e+03],
#        ...,
#        [ 1.00000000e+00,  2.00000000e+00,  1.46169417e+09, ...,
#          5.46732817e+03, -3.01861190e+03,  1.66663085e+03],
#        [ 1.00000000e+00,  2.00000000e+00,  1.45712325e+09, ...,
#          5.46754819e+03, -3.01681380e+03,  1.66457893e+03],
#        [ 1.00000000e+00,  1.00000000e+00,  1.46714105e+09, ...,
#          5.47626197e+03, -3.01479638e+03,  1.65970826e+03]])

# %%
lr2 = LinearRegression().fit(X_p, y_train)
X_p_test=p.fit_transform(X_test)
y_pred = lr2.predict(X_p_test)
print(f'MAE: {mean_absolute_error(y_test, y_pred)}')
print(f'MSE: {mean_squared_error(y_test, y_pred)}')
print(f'RMSE: {sqrt(mean_squared_error(y_test, y_pred))}')
print(f'MAPE: {mean_absolute_percentage_error(y_test, y_pred)}')
print(f'R^2: {lr2.score(X_test, y_test)}')
lr2.coef_
# Out:
# MAE: 0.3455161289591438
# MSE: 8.735223171269936
# RMSE: 2.9555410961903297
# MAPE: 0.0007619162541575903
# R^2: 1.0
# array([ 9.57875667e-07, -2.40327719e-05, -1.23177012e-04,  1.22704522e-04,
#        -1.12525171e-06,  1.10527582e-08, -7.67247360e-06,  4.13183032e-09,
#        -2.13863011e-10,  5.70197891e-05,  2.47037866e-06, -2.46982867e-06,
#        -1.75880389e-04,  7.68734300e-03,  1.14170543e-02,  7.70946198e-03,
#        -3.59060421e-03, -6.60348804e-09,  1.31979930e-08, -1.17243149e-06,
#         1.20613889e-02,  1.23827700e-06, -1.12997572e-03, -4.38401602e-03,
#        -6.59450447e-09,  1.17244777e-06, -1.20613743e-02, -1.23900080e-06,
#         1.12997088e-03,  4.38401294e-03,  1.28317764e-03,  8.27138856e-05,
#        -3.96763381e-04,  8.25803533e-05, -4.64653407e-05, -2.98058325e-07,
#         9.73111808e-04, -7.25104165e-07,  4.50575569e-07,  3.01421804e-03,
#         7.14736205e-04, -1.54894933e-04, -3.50282315e-07,  3.88589006e-07,
#         3.25789425e-08])

# %%
#Poli1
parameters = {'alpha': np.arange(0, 1, 0.1)}
lasso_p_optimal = GridSearchCV(Lasso(), parameters).fit(X_p, y_train)
alpl_p=lasso_p_optimal.best_params_['alpha']
print(alpl_p)
# Out:
# C:\machine_learning\venv\lib\site-packages\sklearn\model_selection\_validation.py:686: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.434e+10, tolerance: 1.101e+07 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\model_selection\_validation.py:686: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.647e+10, tolerance: 1.144e+07 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\model_selection\_validation.py:686: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.344e+10, tolerance: 1.083e+07 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\model_selection\_validation.py:686: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.744e+10, tolerance: 9.628e+06 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\model_selection\_validation.py:686: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   estimator.fit(X_train, y_train, **fit_params)
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.680e+10, tolerance: 7.471e+06 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.434e+10, tolerance: 1.101e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.647e+10, tolerance: 1.144e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.344e+10, tolerance: 1.083e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.744e+10, tolerance: 9.628e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.680e+10, tolerance: 7.471e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.434e+10, tolerance: 1.101e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.647e+10, tolerance: 1.144e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.344e+10, tolerance: 1.083e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.744e+10, tolerance: 9.628e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.680e+10, tolerance: 7.471e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.434e+10, tolerance: 1.101e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.647e+10, tolerance: 1.144e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.344e+10, tolerance: 1.083e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.744e+10, tolerance: 9.628e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.680e+10, tolerance: 7.471e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.434e+10, tolerance: 1.101e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.647e+10, tolerance: 1.144e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.344e+10, tolerance: 1.083e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.744e+10, tolerance: 9.628e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.680e+10, tolerance: 7.471e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.434e+10, tolerance: 1.101e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.647e+10, tolerance: 1.144e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.344e+10, tolerance: 1.083e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.744e+10, tolerance: 9.628e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.680e+10, tolerance: 7.471e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.434e+10, tolerance: 1.101e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.647e+10, tolerance: 1.144e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.344e+10, tolerance: 1.083e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.744e+10, tolerance: 9.628e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.680e+10, tolerance: 7.471e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.434e+10, tolerance: 1.101e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.647e+10, tolerance: 1.144e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.344e+10, tolerance: 1.083e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.744e+10, tolerance: 9.628e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.680e+10, tolerance: 7.471e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.434e+10, tolerance: 1.101e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.647e+10, tolerance: 1.144e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.344e+10, tolerance: 1.083e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.744e+10, tolerance: 9.628e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.680e+10, tolerance: 7.471e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.434e+10, tolerance: 1.101e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.647e+10, tolerance: 1.144e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 5.344e+10, tolerance: 1.083e+07
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 4.744e+10, tolerance: 9.628e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 3.680e+10, tolerance: 7.471e+06
#   model = cd_fast.enet_coordinate_descent(
# C:\machine_learning\venv\lib\site-packages\sklearn\model_selection\_search.py:909: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   self.best_estimator_.fit(X, y, **fit_params)
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# 0.0
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.214e+10, tolerance: 1.260e+07 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(

# %%
lasso_p = Lasso(alpha = alpl_p).fit(X_p, y_train)
y_pred = lasso_p.predict(X_p_test)

print(f'MAE: {mean_absolute_error(y_test, y_pred)}')
print(f'MSE: {mean_squared_error(y_test, y_pred)}')
print(f'RMSE: {sqrt(mean_squared_error(y_test, y_pred))}')
print(f'MAPE: {mean_absolute_percentage_error(y_test, y_pred)}')
print(f'R^2: {lasso_p.score(X_p_test, y_test)}')
lasso_p.coef_
# Out:
# C:\Users\DNS\AppData\Local\Temp\ipykernel_9164\2865582534.py:1: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   lasso_p = Lasso(alpha = alpl_p).fit(X_p, y_train)
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: UserWarning: Coordinate descent with no regularization may lead to unexpected results and is discouraged.
#   model = cd_fast.enet_coordinate_descent(
# MAE: 532.4498935865441
# MSE: 7755669.171297495
# RMSE: 2784.90020849895
# MAPE: 1.2733939356385893
# R^2: 0.01948711864522512
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.214e+10, tolerance: 1.260e+07 Linear regression models with null weight for the l1 regularization term are more efficiently fitted using one of the solvers implemented in sklearn.linear_model.Ridge/RidgeCV instead.
#   model = cd_fast.enet_coordinate_descent(
# array([ 0.00000000e+00, -2.05772751e-01, -3.66695111e-04,  3.90802175e-04,
#         1.28153254e+00,  3.71818928e+03, -9.81839927e-01,  2.83156441e+03,
#        -8.60170284e+03, -2.46148264e-01,  5.94888077e-08,  1.99940021e-11,
#         1.00706008e-01,  1.25296338e-02, -4.25447310e-02, -1.39529853e-02,
#         1.99104080e-02, -1.37057623e-13,  6.69989566e-14, -4.71087858e-08,
#         2.48866198e-06, -1.61810051e-10,  1.38040844e-07, -2.76518785e-08,
#         1.33769133e-13,  9.99229941e-09, -1.63542989e-07, -2.40130290e-10,
#         1.36117660e-07, -2.62681289e-08, -1.76279189e+01, -2.07629316e+00,
#        -3.11879103e-01, -1.89797713e-01,  1.10339290e-01,  3.34058677e+01,
#        -1.83789933e-02, -3.89460176e+01, -6.28420573e+00,  2.52040266e-02,
#         1.34308689e-01,  1.55244595e-03,  2.23614648e+01,  1.82827989e+01,
#         5.30244122e+01])

# %%
#Poli2
ridge_p_optimal = GridSearchCV(Ridge(), parameters).fit(X_p, y_train)
alpr_p=ridge_p_optimal.best_params_['alpha']
print(alpr_p)
# Out:
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.52197e-38): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.51903e-38): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=3.04919e-38): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=4.57503e-38): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=5.91029e-38): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=5.97119e-38): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=6.10265e-38): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=7.1739e-38): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=7.21866e-38): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.43336e-38): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=9.5322e-38): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=9.66269e-38): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.08676e-37): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.09072e-37): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# 0.8
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=1.21611e-37): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.75794e-38): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T

# %%
ridge_p = Ridge(alpha = alpr_p).fit(X_p, y_train)
y_pred = ridge_p.predict(X_p_test)

print(f'MAE: {mean_absolute_error(y_test, y_pred)}')
print(f'MSE: {mean_squared_error(y_test, y_pred)}')
print(f'RMSE: {sqrt(mean_squared_error(y_test, y_pred))}')
print(f'MAPE: {mean_absolute_percentage_error(y_test, y_pred)}')
print(f'R^2: {ridge_p.score(X_p_test, y_test)}')
ridge_p.coef_
# Out:
# MAE: 0.007889390091050814
# MSE: 0.004101182776202167
# RMSE: 0.06404047763877287
# MAPE: 1.5200370722968545e-05
# R^2: 0.9999999994815066
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_ridge.py:216: LinAlgWarning: Ill-conditioned matrix (rcond=8.75794e-38): result may not be accurate.
#   return linalg.solve(A, Xy, assume_a="pos", overwrite_a=True).T
# array([ 0.00000000e+00, -3.60408599e-03, -1.01612382e+00,  1.01612316e+00,
#        -3.68442914e-03,  5.49414859e-04,  3.11868956e-02,  4.12779006e-04,
#        -1.44458667e-04, -2.56345692e-07, -4.07257337e-08,  4.07254185e-08,
#         5.76385817e-06,  2.83159453e-04,  1.99598914e-05, -2.68052343e-04,
#         1.08412081e-04,  1.42628144e-10, -2.85788838e-10, -3.23834984e-07,
#        -3.18019327e-04,  4.37339353e-08,  1.21728062e-04,  5.86354428e-05,
#         1.43160677e-10,  3.23837175e-07,  3.18005895e-04, -4.37326852e-08,
#        -1.21723100e-04, -5.86334178e-05, -3.04677230e-05, -6.91566662e-04,
#        -1.06064224e-05, -5.14476094e-04, -2.16897705e-03, -1.40761003e-01,
#         2.27245156e-04,  3.89631579e-02,  2.63838717e-02, -3.86621906e-04,
#        -1.34835447e-03,  8.43255092e-04,  3.95036853e-02,  4.65259983e-02,
#         2.92423411e-02])

# %%
lasso = Lasso(alpha=alpl).fit(X_train, y_train)
y_pred = lasso.predict(X_test)
print(f'MAE: {mean_absolute_error(y_test, y_pred)}')
print(f'MSE: {mean_squared_error(y_test, y_pred)}')
print(f'RMSE: {sqrt(mean_squared_error(y_test, y_pred))}')
print(f'MAPE: {mean_absolute_percentage_error(y_test, y_pred)}')
print(f'R^2: {lasso.score(X_test, y_test)}')
lasso.coef_
# Out:
# MAE: 533.4168882505469
# MSE: 7777591.081357977
# RMSE: 2788.8332831773896
# MAPE: 1.2748113467985704
# R^2: 0.01671563436405543
# C:\machine_learning\venv\lib\site-packages\sklearn\linear_model\_coordinate_descent.py:631: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations, check the scale of the features or consider increasing regularisation. Duality gap: 6.233e+10, tolerance: 1.260e+07
#   model = cd_fast.enet_coordinate_descent(
# array([ 1.27609176e-02, -3.75687733e-04,  3.91314802e-04,  7.44087894e+00,
#         4.60520744e+03, -8.32335088e-01,  3.24494992e+03, -4.78609998e+03])

# %%
class MyRidge:
    def __init__( self, learning_rate=0.0001, iterations=1000, alpha=0.5 ) :
        self.learning_rate = learning_rate        
        self.iterations = iterations        
        self.alpha = alpha

    def transform_(self, x):
        return np.concatenate((np.ones((len(x), 1)), x), axis = 1)

    def loss_func(self, x, y, w):
        return sum(y - np.dot(x, w)) ** 2  + self.alpha * (np.matmul(w, w))/x.shape[0]

    def fit(self, x, y):
        dist = np.inf
        eps = 1e-20
        X = self.transform_(x)

        w = np.zeros(X.shape[1])
        iter = 0

        while iter <= self.iterations:
            loss = self.loss_func(X, y, w)
            w = w - ((self.learning_rate * 2 * np.dot(X.T, np.dot(X, w) - y)) + ( 2 * self.alpha * w ))/X.shape[0]
            dist = np.abs(loss - self.loss_func(X, y, w))
            iter += 1
            
            if(dist <= eps):
                break
        self.w = w
        return self
        

    def predict(self, x):
        return np.dot(self.transform_(x), self.w)

# %%
def R2(y_test, y_pred):
    numerator = ((y_test - y_pred) ** 2).sum()
    denominator = (
        (y_test - np.average(y_test, axis=0)) ** 2
        ).sum()
    return 1 - (numerator / denominator)
    
def MAPE(y_test, y_pred):
    return np.mean(np.abs((y_test - y_pred)/y_test))
    
def RMSE(y_test, y_pred):
    return np.sqrt(MSE(y_test, y_pred))
    
def MSE(y_test, y_pred):
    return np.mean((y_test - y_pred)**2)
    
def MAE(y_test, y_pred):
    return np.mean(np.abs((y_test - y_pred)))

# %%
ridge = MyRidge()
ridge.fit(X_train, y_train)
y_pred = ridge.predict(X_test)
print(f'MAE: {MAE(y_test, y_pred)}')
print(f'MSE: {MSE(y_test, y_pred)}')
print(f'RMSE: {RMSE(y_test, y_pred)}')
print(f'MAPE: {MAPE(y_test, y_pred)}')
print(f'R^2: {R2(y_test, y_pred)}')
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# Cell In[41], line 2
#       1 ridge = MyRidge()
# ----> 2 ridge.fit(X_train, y_train)
#       3 y_pred = ridge.predict(X_test)
#       4 print(f'MAE: {MAE(y_test, y_pred)}')
#
# Cell In[39], line 24, in MyRidge.fit(self, x, y)
#      22 loss = self.loss_func(X, y, w)
#      23 w = w - ((self.learning_rate * 2 * np.dot(X.T, np.dot(X, w) - y)) + ( 2 * self.alpha * w ))/X.shape[0]
# ---> 24 dist = np.abs(loss - self.loss_func(X, y, w))
#      25 iter += 1
#      27 if(dist <= eps):
#
# Cell In[39], line 11, in MyRidge.loss_func(self, x, y, w)
#      10 def loss_func(self, x, y, w):
# ---> 11     return sum(y - np.dot(x, w)) ** 2  + self.alpha * (np.matmul(w, w))/x.shape[0]
#
# OverflowError: (34, 'Result too large')

# %%
data = data.dropna()

# %%
data
# Out:
#         vendor_id  pickup_datetime  dropoff_datetime  passenger_count  \
# 0             2.0     1.456742e+09      1.456743e+09                1
# 1             1.0     1.457718e+09      1.457719e+09                2
# 2             2.0     1.456056e+09      1.456058e+09                2
# 3             2.0     1.451965e+09      1.451967e+09                6
# 4             1.0     1.455670e+09      1.455671e+09                1
# ...           ...              ...               ...              ...
# 729317        2.0     1.463816e+09      1.463816e+09                2
# 729318        1.0     1.456080e+09      1.456081e+09                1
# 729319        1.0     1.460725e+09      1.460726e+09                1
# 729320        1.0     1.466308e+09      1.466309e+09                1
# 729321        2.0     1.451647e+09      1.451649e+09                4
#
#         pickup_longitude  pickup_latitude  dropoff_longitude  \
# 0             -73.953918        40.778873         -73.963875
# 1             -73.988312        40.731743         -73.994751
# 2             -73.997314        40.721458         -73.948029
# 3             -73.961670        40.759720         -73.956779
# 4             -74.017120        40.708469         -73.988182
# ...                  ...              ...                ...
# 729317        -73.965919        40.789780         -73.952637
# 729318        -73.996666        40.737434         -74.001320
# 729319        -73.997849        40.761696         -74.001488
# 729320        -74.006706        40.708244         -74.013550
# 729321        -74.003342        40.743839         -73.945847
#
#         dropoff_latitude  trip_duration
# 0              40.771164            400
# 1              40.694931           1100
# 2              40.774918           1635
# 3              40.780628           1141
# 4              40.740631            848
# ...                  ...            ...
# 729317         40.789181            296
# 729318         40.731911            315
# 729319         40.741207            673
# 729320         40.713814            447
# 729321         40.712841           1224
#
# [729322 rows x 9 columns]

# %%
from sklearn.model_selection import train_test_split
data=data.sample(20000)
X = data.iloc[:, :-1].values
Y = data.iloc[:, 8].values
X_train, X_test, y_train, y_test = train_test_split( X, Y, test_size = 0.3, random_state = 0 )

# %%
class RidgeRegression_() :
      
    def __init__(self, learning_rate=0.01, iterations=1000, Alpha=0.0) :
          
        self.learning_rate = learning_rate        
        self.iterations = iterations        
        self.Alpha = Alpha
       
    def fit( self, X, Y ) :  
        self.m, self.n = X.shape
       
        self.W = np.zeros(self.n)
          
        self.b = 0        
        self.X = X        
        self.Y = Y
          
        for i in range( self.iterations ) :            
            self.update_weights()      
        return self
      
    def update_weights( self ) :           
        Y_pred = self.predict( self.X )
   
        dW = ( - ( 2 * ( self.X.T ).dot( self.Y - Y_pred ) ) +               
               ( 2 * self.Alpha * self.W ) ) / self.m     
        db = - 2 * np.sum( self.Y - Y_pred ) / self.m 
   
        self.W = self.W - self.learning_rate * dW    
        self.b = self.b - self.learning_rate * db        
        return self
      
    def predict( self, X ) :    
        return X.dot( self.W ) + self.b

# %%
class Ridge_:
        
    def __init__(self, Alpha=1.0):
        self.Alpha = Alpha;
    
    def fit(self, X, y):
        m, n = np.shape(X)
        upper_half = np.hstack((np.ones((m, 1)), X))
        lower = np.zeros((n, n))
        np.fill_diagonal(lower, np.sqrt(1.0))
        lower_half = np.hstack((np.zeros((n, 1)), lower))
        X = np.vstack((upper_half, lower_half))
        y = np.append(y, np.zeros(n))
        self.coef_ = np.linalg.solve(np.dot(X.T, X), np.dot(X.T, y))
        return self
    
    def predict(self, X):
        return np.dot(X, self.coef_[1:9]) + self.coef_[0]
        
    def MAE_(self, y_test, y_pred):
        return sum(abs(y_test - y_pred))/y_test.shape[0]

    def MSE_(self, y_test, y_pred):
        return sum((y_test - y_pred)**2)/y_test.shape[0]

    def RMSE_(self, y_test, y_pred):
        return np.sqrt(sum((y_test - y_pred)**2)/y_test.shape[0])

    def MAPE_(self, y_test, y_pred):
        return (sum(abs((y_test - y_pred)/y_test)))/y_test.shape[0]

    def R_2(self, y_test, y_pred):
        return 1 - (sum((y_test - y_pred)**2)/y_test.shape[0])/(sum((y_test - np.mean(y_test))**2)/y_test.shape[0])

# %%
lr = RidgeRegression_(Alpha=1.0).fit(X_train, y_train)
# Out:
# C:\Users\DNS\AppData\Local\Temp\ipykernel_11420\1908087113.py:25: RuntimeWarning: overflow encountered in matmul
#   dW = (self.X @ (A-self.Y).T)/self.m
# C:\Users\DNS\AppData\Local\Temp\ipykernel_11420\1908087113.py:25: RuntimeWarning: invalid value encountered in matmul
#   dW = (self.X @ (A-self.Y).T)/self.m
# C:\Users\DNS\AppData\Local\Temp\ipykernel_11420\1908087113.py:32: RuntimeWarning: invalid value encountered in subtract
#   self.W = self.W - self.learning_rate * dW

# %%
y_pred = lr.predict(X_test)

# %%
lr.predict(X_test)
# Out:
# array([nan, nan, nan, ..., nan, nan, nan])

# %%
y_test
# Out:
# array([1423,  321,  509, ...,  494,  301,  428], dtype=int64)

# %%
y_test.shape[0]
# Out:
# 6000

# %%
lr.coef_
# Out:
# array([-2.65143630e+02, -4.40161123e-02, -1.00035251e+00,  1.00035251e+00,
#        -3.72797363e-03, -1.43400516e+00,  1.29444602e+00, -9.22558963e-01,
#         1.08743735e+00])

# %%
print('MAE: ', lr.MAE_(y_test, y_pred))
print('MSE: ', lr.MSE_(y_test, y_pred))
print('RMAE: ', lr.RMSE_(y_test, y_pred))
print('MApE: ', lr.MAPE_(y_test, y_pred))
print('R_2: ', lr.R_2(y_test, y_pred))
# Out:
# MAE:  0.21721491606905813
# MSE:  1.7789825879178076
# RMAE:  1.3337850606142685
# MApE:  0.0005221186411883252
# R_2:  0.9999998762860768

# %%
class LinReg:
    
    def Ridge(self, Alpha):
        self.Alpha = Alpha;
        
    def __init__(self, lr=0.001, iters=5000, eps=0.001, Alpha=0.0):
        self.lr = lr
        self.iters = iters
        self.eps = eps
        self.Alpha = Alpha;
    
    def fit(self, X, y):
        dist = np.inf
        w = np.zeros(X.shape[1])
        iter = 0
        while dist > self.eps and iter <= self.iters:
            loss = self.fun_error(X, y, w)
            w = w - (self.lr * 2 * np.dot(X.T, np.dot(X, w) - y) / X.shape[0]) + self.Alpha * 2 / X.shape[0]
            dist = np.abs(loss - self.fun_error(X, y, w))
            iter += 1
        self.w = w  
    
    def transform(self, X):
        return np.concatenate(np.ones((len(X), 1)), axis=1)


    def fun_error(self, X, y, w):
        return sum((y - np.dot(X, w)) ** 2) / X.shape[0]
    
    def predict(self, X):
        return np.dot(X, self.w)
        
    

    
    def MAE_(self, y_test, y_pred):
        return sum(abs(y_test - y_pred))/y_test.shape

    def MSE_(self, y_test, y_pred):
        return sum((y_test - y_pred)**2)/y_test.shape

    def RMSE_(self, y_test, y_pred):
        return np.sqrt(sum((y_test - y_pred)**2)/y_test.shape)

    def MAPE_(self, y_test, y_pred):
        return (sum(abs((y_test - y_pred)/y_test)))/y_test.shape

    def R_2(self, y_test, y_pred):
        return 1 - (MSE(y_test, y_pred))/(sum(y_test - np.mean(y_test))/y_test.shape)

# %%
lr = LinReg()
lr.fit(X, y)
y_pred = lr.predict(X_test)
print(y_pred.shape, y_test.shape)
print(y_pred)
print(y_test)
print('MAE: ', lr.MAE_(y_test, y_pred))
print('MSE: ', lr.MSE_(y_test, y_pred))
print('RMAE: ', lr.RMSE_(y_test, y_pred))
print('MApE: ', lr.MAPE_(y_test, y_pred))
print('R_2: ', lr.R_2(y_test, y_pred))
# Out:
# (4000,) (4000,)
# [1.63002313e+178 1.61513801e+178 1.62312942e+178 ... 1.62499022e+178
#  1.61870346e+178 1.62749438e+178]
# 17356    543
# 5296     803
# 4018     274
# 5003     334
# 14442    502
#         ...
# 15424    688
# 15397    166
# 14906    327
# 9719     595
# 12805    897
# Name: trip_duration, Length: 4000, dtype: int64
# C:\Users\DNS\AppData\Local\Temp\ipykernel_15780\4163948044.py:28: RuntimeWarning: overflow encountered in square
#   return sum((y - np.dot(X, w)) ** 2) / X.shape[0]
# C:\Users\DNS\AppData\Local\Temp\ipykernel_15780\4163948044.py:19: RuntimeWarning: invalid value encountered in scalar subtract
#   dist = np.abs(loss - self.fun_error(X, y, w))
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[213], line 7
#       5 print(y_pred)
#       6 print(y_test)
# ----> 7 print('MAE: ', lr.MAE_(y_test, y_pred))
#       8 print('MSE: ', lr.MSE_(y_test, y_pred))
#       9 print('RMAE: ', lr.RMSE_(y_test, y_pred))
#
# Cell In[212], line 37, in LinReg.MAE_(self, y_test, y_pred)
#      36 def MAE_(self, y_test, y_pred):
# ---> 37     return sum(abs(y_test - y_pred))/y_test.shape
#
# TypeError: unsupported operand type(s) for /: 'float' and 'tuple'

# %%
data.head(5)
# Out:
#    vendor_id  pickup_datetime  dropoff_datetime  passenger_count  \
# 0        2.0     1.452362e+09      1.452363e+09                1
# 1        1.0     1.459663e+09      1.459663e+09                1
# 2        1.0     1.455025e+09      1.455026e+09                1
# 3        1.0     1.463120e+09      1.463120e+09                1
# 4        1.0     1.455186e+09      1.455187e+09                1
#
#    pickup_longitude  pickup_latitude  dropoff_longitude  dropoff_latitude  \
# 0        -73.967682        40.792725         -73.990227         40.757504
# 1        -74.014114        40.712418         -74.002510         40.719894
# 2        -73.984634        40.768501         -73.972954         40.785343
# 3        -73.953064        40.768284         -73.953651         40.777622
# 4        -73.962204        40.778770         -73.982491         40.764336
#
#    trip_duration
# 0            588
# 1            282
# 2            667
# 3            314
# 4            892

# %%
X = data.iloc[:, :-1].values#data.drop(["trip_duration"], axis=1)
y = data.iloc[:, 8].values#data["trip_duration"]

# %%
print(y.values)
# Out:
# [ 588  282  667 ... 1810  480  458]

# %%
y_pred = lr.predict(X_test)
print(y_pred.shape, y_test.shape)
print(y_pred[3])
print(y_test[3])
print('MAE: ', lr.MAE_(y_test, y_pred))
print('MSE: ', lr.MSE_(y_test, y_pred))
print('RMAE: ', lr.RMSE_(y_test, y_pred))
print('MApE: ', lr.MAPE_(y_test, y_pred))
print('R_2: ', lr.R_2(y_test, y_pred))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[204], line 1
# ----> 1 y_pred = lr.predict(X_test)
#       2 print(y_pred.shape, y_test.shape)
#       3 print(y_pred[3])
#
# AttributeError: 'NoneType' object has no attribute 'predict'

# %%
y_pred = lr.predict(X)
print(y_pred.shape, y_test.shape)
print(y_pred[3])
print(y[3])
# Out:
# (20000,) (4000,)
# -1.9096855098038378e+162
# 314

# %%
#L1 сам.
class Ridge_:
    
    Alpha = 0.5
    
    def __init__(self, Alpha):
        self.Alpha = Alpha;
        
    def fit(self, X, Y):

        self.m, self.n = X.shape
        self.W = np.zeros(self.n)

        self.X = X
        self.Y = Y

    
    def train(self):
        Y_predict = self.predict(self.X)
        
        dW = (-(2 * (self.X.T).dot(self.Y - Y_predict)) + 0.2) / self.m
        db = -2 * np.sum(self.Y - Y_predict) / self.m
        
        self.W = self.W - Alpha*dW
        return self

    def predict(self, X):
        return X.dot(self.W)+self.b    
        
        
    def fit(X, y):
        
    def predict(X_test):
        return np.dot(X, self.w)

# %%
#На память. Бесполезно.
def MAE(X, y):
    #X=X.as_matrix()
    w=np.linalg.pinv(X.transpose().dot(X)).dot(X.transpose()).dot(y)
    s=0
    m=len(X.axes[0])
    n=len(X.axes[1])
    for i in range(m):
        y_=0
        for j in range(n):
            y_+=w[j]*X.iat[i,j]
        s+=abs(y.iat[i]-y_)
    s1=s/m
    return(s1)
def MSE(X, y):
    #X=X.as_matrix()
    w=np.linalg.pinv(X.transpose().dot(X)).dot(X.transpose()).dot(y)
    s=0
    m=len(X.axes[0])
    n=len(X.axes[1])
    for i in range(m):
        y_=0
        for j in range(n):
            y_+=w[j]*X.iat[i,j]
        s+=(y.iat[i]-y_)**2
    s1=s/m
    return(s1)
def RMSE(X, y):
    #X=X.as_matrix()
    w=np.linalg.pinv(X.transpose().dot(X)).dot(X.transpose()).dot(y)
    s=0
    m=len(X.axes[0])
    n=len(X.axes[1])
    for i in range(m):
        y_=0
        for j in range(n):
            y_+=w[j]*X.iat[i,j]
        s+=(y.iat[i]-y_)**2
    s1=sqrt(s/m)
    return(s1)
def MAPE(X, y):
    #X=X.as_matrix()
    w=np.linalg.pinv(X.transpose().dot(X)).dot(X.transpose()).dot(y)
    s=0
    m=len(X.axes[0])
    n=len(X.axes[1])
    for i in range(m):
        y_=0
        for j in range(n):
            y_+=w[j]*X.iat[i,j]
        s+=abs((y.iat[i]-y_)/y.iat[i])
    s1=s/m
    return(s1)
def R_2(X, y):
    #X=X.as_matrix()
    w=np.linalg.pinv(X.transpose().dot(X)).dot(X.transpose()).dot(y)
    s=0
    m=len(X.axes[0])
    for i in range(m):
        y_=y.mean()
        s+=(y.iat[i]-y_)**2
    s1=s/m
    return(1-(MSE(X,y)/s1))

# %%
print('MAE: ', MAE(X_train, y_train))
print('MSE: ', MSE(X_train, y_train))
print('RMAE: ', RMSE(X_train, y_train))
print('MApE: ', MAPE(X_train, y_train))
print('R_2: ', R_2(X_train, y_train))

print('MAE: ', MAE(X_test, y_test))
print('MSE: ', MSE(X_test, y_test))
print('RMAE: ', RMSE(X_test, y_test))
print('MApE: ', MAPE(X_test, y_test))
print('R_2: ', R_2(X_test, y_test))
# Out:
# MAE:  590.2542204070038
# MSE:  8323202.462563874
# RMAE:  2884.996094029223
# MApE:  1.5424568755059902
# R_2:  0.0013341793824208636
# MAE:  661.7032032607909
# MSE:  12457237.688627644
# RMAE:  3529.481220891768
# MApE:  1.674886310303826
# R_2:  0.0003117740852730533
